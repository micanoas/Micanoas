# %% [markdown]
# <a href="https://colab.research.google.com/github/micanoas/Micanoas/blob/main/Fun%C3%A7%C3%B5es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_prouni = pd.read_excel('/cursos-prouni.csv.xlsx')

# %%
df_prouni
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral      9999.99                  15.0
# 1       Bacharelado            Noturno      9836.40                   1.0
# 2       Bacharelado           Integral      9715.61                   2.0
# 3       Bacharelado            Noturno      9689.34                   3.0
# 4       Bacharelado           Integral      9674.34                   4.0
# ...             ...                ...          ...                   ...
# 41442  Licenciatura  Curso a Distância       149.00                   1.0
# 41443   Tecnológico  Curso a Distância       144.00                   1.0
# 41444   Tecnológico         Vespertino       139.00                   1.0
# 41445   Bacharelado  Curso a Distância       139.00                   1.0
# 41446   Tecnológico  Curso a Distância       139.00                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
df_prouni['curso_busca'].value_counts()
# Out:
# curso_busca
# Administração                         2754
# Pedagogia                             2555
# Ciências Contábeis                    2056
# Gestão de Recursos Humanos            1595
# Educação Física                       1528
#                                       ...
# Mídias Sociais                           1
# Agropecuária                             1
# Engenharia de Produção e Qualidade       1
# Química Industrial                       1
# Sistemas de Segurança Pública            1
# Name: count, Length: 296, dtype: int64

# %%
df_prouni['mensalidade'].max()
# Out:
# 9999.99

# %%
df_prouni.groupby(['uf_busca'])['mensalidade'].agg([sum])
# Out:
# <ipython-input-9-e6a75df9b6d4>:1: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df_prouni.groupby(['uf_busca'])['mensalidade'].agg([sum])
#                  sum
# uf_busca
# AC         115860.96
# AL         174775.38
# AM         247383.69
# AP         126685.35
# BA        1602821.25
# CE         654150.36
# DF         708968.98
# ES         512552.58
# GO         712595.49
# MA         494741.54
# MG        2792888.80
# MS         362447.15
# MT         522513.98
# PA         623230.66
# PB         415158.12
# PE         729083.81
# PI         254947.88
# PR        2359939.35
# RJ        1074994.24
# RN         232422.41
# RO         306503.46
# RR          47574.59
# RS        2273590.61
# SC        1230707.10
# SE         207392.30
# SP        6820708.48
# TO         201795.80

# %%
df_prouni.groupby(['uf_busca'])['mensalidade'].agg(['mean'])
# Out:
#                 mean
# uf_busca
# AC        570.743645
# AL        534.481284
# AM        576.651958
# AP        578.471918
# BA        639.848802
# CE        801.654853
# DF        666.951063
# ES        621.275855
# GO        557.586455
# MA        728.632607
# MG        668.955401
# MS        461.716115
# MT        491.546548
# PA        518.926445
# PB        696.574027
# PE        635.090427
# PI        629.500938
# PR        602.332657
# RJ        745.488377
# RN        679.597690
# RO        661.994514
# RR        428.599910
# RS        743.003467
# SC        560.686606
# SE        642.081424
# SP        591.408001
# TO        588.325948

# %%
df_prouni.groupby(['uf_busca','curso_busca'])['mensalidade'].agg(['mean'])
# Out:
#                                                        mean
# uf_busca curso_busca
# AC       Administração                           422.846667
#          Análise e Desenvolvimento de Sistemas   360.000000
#          Arquitetura e Urbanismo                1111.300000
#          Artes VIsuais                           237.000000
#          Biblioteconomia                         356.800000
# ...                                                     ...
# TO       Sistema de Informação                   749.500000
#          Sistemas de Informação                  939.540000
#          Sociologia                              189.500000
#          Teologia                                204.250000
#          Turismo                                 404.245000
#
# [2715 rows x 1 columns]

# %%
df_prouni.groupby(['uf_busca','curso_busca'])['mensalidade'].agg(['mean']).sort_values(by=['uf_busca','mean'])
# Out:
#                                                   mean
# uf_busca curso_busca
# AC       Negócios Imobiliários              170.000000
#          Teologia                           189.000000
#          Sociologia                         189.500000
#          Filosofia                          233.500000
#          Artes VIsuais                      237.000000
# ...                                                ...
# TO       Engenharia Ambiental e Sanitária  1251.240000
#          Engenharia de Minas               1314.740000
#          Medicina Veterinária              2059.575000
#          Odontologia                       2193.836000
#          Medicina                          7690.156667
#
# [2715 rows x 1 columns]

# %%
def duplica_bolsas(rows):
  nova_bolsa = rows * 2
  return nova_bolsa

# %%
df = df_prouni[['uf_busca', 'curso_busca', 'mensalidade', 'bolsa_integral_ampla']]
df
# Out:
#       uf_busca                 curso_busca  mensalidade  bolsa_integral_ampla
# 0           MS                    Medicina      9999.99                  14.0
# 1           CE                  Enfermagem      9836.40                   NaN
# 2           SP                    Medicina      9715.61                   5.0
# 3           CE                  Psicologia      9689.34                   2.0
# 4           AC                    Medicina      9674.34                   1.0
# ...        ...                         ...          ...                   ...
# 41442       TO                  Sociologia       149.00                   NaN
# 41443       SP                   Marketing       144.00                   2.0
# 41444       DF  Gestão de Recursos Humanos       139.00                   NaN
# 41445       ES              Serviço Social       139.00                   NaN
# 41446       PA            Gestão Ambiental       139.00                   1.0
#
# [41447 rows x 4 columns]

# %%
df['nova_bolsa'] = df['bolsa_integral_ampla'].apply(duplica_bolsa)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7102f334e4a1> in <cell line: 1>()
# ----> 1 df['nova_bolsa'] = df['bolsa_integral_ampla'].apply(duplica_bolsa)
#
# NameError: name 'duplica_bolsa' is not defined

# %%
df
# Out:
#       uf_busca                 curso_busca  mensalidade  bolsa_integral_ampla
# 0           MS                    Medicina      9999.99                  14.0
# 1           CE                  Enfermagem      9836.40                   NaN
# 2           SP                    Medicina      9715.61                   5.0
# 3           CE                  Psicologia      9689.34                   2.0
# 4           AC                    Medicina      9674.34                   1.0
# ...        ...                         ...          ...                   ...
# 41442       TO                  Sociologia       149.00                   NaN
# 41443       SP                   Marketing       144.00                   2.0
# 41444       DF  Gestão de Recursos Humanos       139.00                   NaN
# 41445       ES              Serviço Social       139.00                   NaN
# 41446       PA            Gestão Ambiental       139.00                   1.0
#
# [41447 rows x 4 columns]

# %%
df['nova_bolsa'] = df['nova_bolsa'].fillna(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'nova_bolsa'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-7f7869647d1c> in <cell line: 1>()
# ----> 1 df['nova_bolsa'] = df['nova_bolsa'].fillna(1)
#
# ...

# %%
df
# Out:
#       uf_busca                 curso_busca  mensalidade  bolsa_integral_ampla
# 0           MS                    Medicina      9999.99                  14.0
# 1           CE                  Enfermagem      9836.40                   NaN
# 2           SP                    Medicina      9715.61                   5.0
# 3           CE                  Psicologia      9689.34                   2.0
# 4           AC                    Medicina      9674.34                   1.0
# ...        ...                         ...          ...                   ...
# 41442       TO                  Sociologia       149.00                   NaN
# 41443       SP                   Marketing       144.00                   2.0
# 41444       DF  Gestão de Recursos Humanos       139.00                   NaN
# 41445       ES              Serviço Social       139.00                   NaN
# 41446       PA            Gestão Ambiental       139.00                   1.0
#
# [41447 rows x 4 columns]

# %%
df['nova_bolsa_lambda'] = df['bolsa_integral_ampla'].apply(lambda x: x * 2)
# Out:
# <ipython-input-27-17198cf8ee00>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['nova_bolsa_lambda'] = df['bolsa_integral_ampla'].apply(lambda x: x * 2)

# %%
df
# Out:
#       uf_busca                 curso_busca  mensalidade  bolsa_integral_ampla  \
# 0           MS                    Medicina      9999.99                  14.0
# 1           CE                  Enfermagem      9836.40                   NaN
# 2           SP                    Medicina      9715.61                   5.0
# 3           CE                  Psicologia      9689.34                   2.0
# 4           AC                    Medicina      9674.34                   1.0
# ...        ...                         ...          ...                   ...
# 41442       TO                  Sociologia       149.00                   NaN
# 41443       SP                   Marketing       144.00                   2.0
# 41444       DF  Gestão de Recursos Humanos       139.00                   NaN
# 41445       ES              Serviço Social       139.00                   NaN
# 41446       PA            Gestão Ambiental       139.00                   1.0
#
#        nova_bolsa_lambda
# ...

# %%
df = df.assign(nova_bolsa_lambda2 = lambda x : (x['bolsa_integral_ampla'] * 2))

# %%
df
# Out:
#       uf_busca                 curso_busca  mensalidade  bolsa_integral_ampla  \
# 0           MS                    Medicina      9999.99                  14.0
# 1           CE                  Enfermagem      9836.40                   NaN
# 2           SP                    Medicina      9715.61                   5.0
# 3           CE                  Psicologia      9689.34                   2.0
# 4           AC                    Medicina      9674.34                   1.0
# ...        ...                         ...          ...                   ...
# 41442       TO                  Sociologia       149.00                   NaN
# 41443       SP                   Marketing       144.00                   2.0
# 41444       DF  Gestão de Recursos Humanos       139.00                   NaN
# 41445       ES              Serviço Social       139.00                   NaN
# 41446       PA            Gestão Ambiental       139.00                   1.0
#
# ...
